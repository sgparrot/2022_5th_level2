# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
N, D, H = 64,1000,100
x = tf.placehelder(tf.float32, shape = (N,D))
y = tf.placehelder(tf.float32, shape = (N,D))
w1 = tf.placehelder(tf.float32, shape = (D,H))
w2 = tf.placehelder(tf.float32, shape = (D,H))

# %%
h = tf.maximum(tf.matmul(x,w1),0)  #relu function
y_pred = tf.matmul(h,w2)
diff = y_pred - y
loss = tf.reduce_mean(tf.reduce)
