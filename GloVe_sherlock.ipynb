# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
import re
from tensorflow.keras.preprocessing.text import Tokenizer
# !pip install glove_python_binary
from glove import Corpus, Glove
# Out:
# Collecting glove_python_binary
#   Downloading glove_python_binary-0.2.0-cp37-cp37m-manylinux1_x86_64.whl (948 kB)
#      |████████████████████████████████| 948 kB 3.6 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from glove_python_binary) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from glove_python_binary) (1.21.5)
# Installing collected packages: glove-python-binary
# Successfully installed glove-python-binary-0.2.0

# %%
f = open("/content/input.txt")
dataset = f.readlines()
print(len(dataset))
# Out:
# 40000

# %%
data = []
def preprocess(text):
  text = re.sub(r"[^A-Za-z ]","", text)
  return text
for i in range(40000):
  if preprocess(dataset[i]) not in ["First Citizen","All","Seocond Citizen","MENENIUS","COMINIUS","MARCIUS","AUFIDIUS","Fisrt Soldier","BRUTUS","","SICINIUS","Both","VOLUMNIA","VIRGILIA","VALERIA"]:
    data.append(preprocess(dataset[i].lower()))

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data)
word_index = tokenizer.word_index

# %%
word_list=[]
for i in range(len(data)):
  word_list.append(data[i].split())

# %%
word_list[:2]
# Out:
# [['before', 'we', 'proceed', 'any', 'further', 'hear', 'me', 'speak'],
#  ['speak', 'speak']]

# %%
corpus = Corpus() 

# 훈련 데이터로부터 GloVe에서 사용할 동시 등장 행렬 생성
corpus.fit(word_list, window=10)
glove = Glove(no_components=300, learning_rate=0.05)

# 학습에 이용할 쓰레드의 개수는 4로 설정, 에포크는 20.
glove.fit(corpus.matrix, epochs=20, no_threads=4, verbose=True)
glove.add_dictionary(corpus.dictionary)
# Out:
# Performing 20 training epochs with 4 threads
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10
# Epoch 11
# Epoch 12
# Epoch 13
# Epoch 14
# Epoch 15
# Epoch 16
# Epoch 17
# Epoch 18
# Epoch 19

# %%
glove_keys=list(glove.dictionary.keys())
glove_index=list(glove.dictionary.values())

# %%
glove_keys[:5]
glove_index[:5]
# Out:
# [0, 1, 2, 3, 4]

# %%
list(glove.word_vectors[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-1c01c920c611> in <module>()
# ----> 1 list(glove.word_vectors[0]).split()
#
# AttributeError: 'list' object has no attribute 'split'

# %%
for index, keys in enumerate(glove.dictionary):
  f.write("{} {}\n",format(keys,list(glove.word_vectors[index])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-4cce64a93aa6> in <module>()
#       1 for index, keys in enumerate(glove.dictionary):
# ----> 2   f.write("{} {}\n",format(keys,list(glove.word_vectors[index])))
#
# TypeError: format() argument 2 must be str, not list

# %%
f = open("sherlock_glove.txt",'w')

# %%
f.write()
